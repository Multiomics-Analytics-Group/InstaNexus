# %% [markdown]
# ## De Bruijn assembly workflow

# %% [raw]
# r""" Full assembly workflow with a dbg approach.
#  _____  _______  _    _
# |  __ \|__   __|| |  | |
# | |  | |  | |   | |  | |
# | |  | |  | |   | |  | |
# | |__| |  | |   | |__| |
# |_____/   |_|   |______|
#
# __authors__ = Marco Reverenna & Konstantinos Kalogeropoulus
# __copyright__ = Copyright 2025-2026
# __research-group__ = DTU Biosustain (Multi-omics Network Analytics) and DTU Bioengineering
# __date__ = 26 Jun 2025
# __maintainer__ = Marco Reverenna
# __email__ = marcor@dtu.dk
# __status__ = Dev
# """

# %%
import os
import sys

script_dir = os.getcwd()
sys.path.append(os.path.join(script_dir, '../src'))

# %%
# my modules
import dbg
import greedy_method as greedy
import mapping as map
import consensus as cons
import alignment as align
import clustering as clus
import preprocessing as prep
import compute_statistics as comp_stat

# import libraries
from tqdm import tqdm
from tempfile import mkdtemp
from itertools import combinations
from collections import defaultdict, Counter
from Bio import SeqIO

import json
import re
import Bio
import shutil
import logging
import importlib
import statistics
import subprocess
import numpy as np
import pandas as pd
import seaborn as sns
import networkx as nx
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
def get_sample_metadata(run, chain="", json_path="../json/sample_metadata.json"):
    with open(json_path, "r") as f:
        all_meta = json.load(f)

    if run not in all_meta:
        raise ValueError(f"Run '{run}' not found in metadata.")

    entries = all_meta[run]

    for entry in entries:
        if entry["chain"] == chain:
            return entry

    raise ValueError(f"No metadata found for run '{run}' with chain '{chain}'.")

# %%
def get_colors_from_run(cat, is_scaffold=False, json_path="../json/colors.json"):
    if not os.path.exists(json_path):
        raise FileNotFoundError(f"Missing color file: {json_path}")

    with open(json_path, "r") as f:
        colors = json.load(f)

    category = cat.split("_")[0].lower()
    key = "scaffold" if is_scaffold else "contig"

    try:
        return colors[category][key]
    except KeyError:
        raise ValueError(f"Color not defined for category '{category}' and key '{key}'")

# %%
def get_combination_name(ass_method, conf, kmer_size, size_threshold, min_overlap, min_identity, max_mismatches):
    if ass_method == "dbg":
        return f"comb_{ass_method}_c{conf}_ks{kmer_size}_ts{size_threshold}_mo{min_overlap}_mi{min_identity}_mm{max_mismatches}"
    else:
        return f"comb_{ass_method}_c{conf}_ts{size_threshold}_mo{min_overlap}_mi{min_identity}_mm{max_mismatches}"

# %%
run = "bsa"

meta = get_sample_metadata(run)

protein = meta["protein"]
chain = meta["chain"]
proteases = meta["proteases"]

# %%
# antibodies,ma3heavy,dbg,comb_dbg_c0.9_ks7_ts0_mo4_mi0.8_mm12,39,0.968,72,0.251,30,0.144,0.939,0.907,0.619
# nb6 comb_dbg_c0.86_ks6_ts0_mo4_mi0.9_mm12
# bd17 comb_dbg_c0.88_ks7_ts10_mo4_mi0.9_mm12
# bd15 comb_dbg_c0.92_ks6_ts0_mo4_mi0.9_mm12

# best contig dbg results

# ma1 heavy comb_dbg_c0.88_ks7_ts0_mo4_mi0.9_mm14
# ma2 heavy comb_dbg_c0.86_ks6_ts0_mo3_mi0.9_mm10
# ma3 heavy comb_dbg_c0.88_ks6_ts0_mo4_mi0.8_mm8

# ma1 light comb_dbg_c0.86_ks7_ts0_mo4_mi0.9_mm8
# ma2 light comb_dbg_c0.92_ks7_ts5_mo3_mi0.9_mm10
# ma3 light comb_dbg_c0.92_ks6_ts10_mo3_mi0.8_mm14

# %%
ass_method = 'dbg'
kmer_size = 6
conf = 0.86
size_threshold = 0
min_overlap = 3
min_identity = 0.9
max_mismatches = 12

# %%
comb = get_combination_name(ass_method, conf, kmer_size, size_threshold, min_overlap, min_identity, max_mismatches)

print(comb)
# Out:
# comb_dbg_c0.86_ks6_ts0_mo3_mi0.9_mm12

# %%
params = {"ass_method": 'dbg',
          "conf": conf,
          "kmer_size": kmer_size,
          "min_overlap": min_overlap,
          "min_identity": min_identity,
          "max_mismatches": max_mismatches,
          "size_threshold": size_threshold
          }

# %%
folder_outputs = f"../outputs/{run}{chain}"

prep.create_directory(folder_outputs)

combination_folder_out = os.path.join(folder_outputs, f"comb_{ass_method}_c{conf}_ks{kmer_size}_ts{size_threshold}_mo{min_overlap}_mi{min_identity}_mm{max_mismatches}")

prep.create_subdirectories_outputs(combination_folder_out)

# %% [markdown]
# ### Data cleaning

# %%
protein_norm = prep.normalize_sequence(protein)

df = pd.read_csv(f"../input/{run}.csv")

# %%
importlib.reload(prep)
prep.missing_values_barplot(run, df, "../figures")
# Out:
# Valid PSMs: 93649 (85.64%)
# Missing PSMs: 15709 (14.36%)
# Total PSMs: 109358

# %%
df['protease'] = df['experiment_name'].apply(lambda name: prep.extract_protease(name, proteases))

df = prep.clean_dataframe(df)

# %%
df['cleaned_preds'] = df['preds'].apply(prep.remove_modifications)

# %%
cleaned_psms = df['cleaned_preds'].tolist()

# %%
filtered_psms = prep.filter_contaminants(cleaned_psms, run, "../fasta/contaminants.fasta")

# %%
df = df[df['cleaned_preds'].isin(filtered_psms)]

# %%
df["mapped"] = df["cleaned_preds"].apply(lambda x: "True" if x in protein_norm else "False")

# %%
importlib.reload(prep)

prep.plot_map_unmap_distribution(df, protein_norm, run, folder = "../figures", conf_lim=0, title = False)

# %%
importlib.reload(prep)
prep.fdr_ratio_mapped_unmapped(run, df, folder = "../figures")

# %%
importlib.reload(prep)

prep.plot_relative_map_distribution(run, df, protein_norm, folder = "../figures")
# Out:
# /Users/marcor/Desktop/Marco/PhD/projects/InstaNexus/notebooks/../src/preprocessing.py:533: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /Users/marcor/Desktop/Marco/PhD/projects/InstaNexus/notebooks/../src/preprocessing.py:534: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /Users/marcor/Desktop/Marco/PhD/projects/InstaNexus/notebooks/../src/preprocessing.py:535: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
importlib.reload(prep)

prep.plot_map_distribution(run, df, protein_norm, threshold=0.88, folder = "../figures")

# %%
df = df[df['conf'] > conf]

# %%
df.reset_index(drop=True, inplace=True)

# %%
final_psms = df['cleaned_preds'].tolist()

# %%
mapped_psms = map.process_protein_contigs_scaffold(final_psms, protein_norm, max_mismatches, min_identity)

# %%
proteases
# Out:
# ['Chymotrypsin',
#  'Legumain',
#  'Krakatoa',
#  'Elastase',
#  'Trypsin',
#  'Papain',
#  'Thermo',
#  'ProtK',
#  'GluC',
#  'LysC']

# %%
custom_colors = [
    "#8dd3c7", # Thermo
    "#ffffb3", # Krakatoa
    "#bebada", # Chymotrypsin
    "#fb8072", # Elastase
    "#80b1d3", # GluC
    "#fdb462", # Trypsin
    "#b3de69", # Papain
    "#fccde5", # ProtK
    "#d9d9d9", # Legumain
    "#bc80bd" # LysC
]

palette = dict(zip(proteases, custom_colors))

# %%
mapped_psms
# Out:
# [('DDKEACFA', (584, 592, [], 1.0)),
#  ('ECFLSHKDD', (123, 132, [], 1.0)),
#  ('KYLCDNQDTLSSKL', (284, 298, [], 1.0)),
#  ('KYNGVFQ', (182, 189, [], 1.0)),
#  ('KYNGVFQ', (182, 189, [], 1.0)),
#  ('ECFLSHKDD', (123, 132, [], 1.0)),
#  ('VMENFVAF', (569, 577, [], 1.0)),
#  ('CFLSHKDD', (124, 132, [], 1.0)),
#  ('RETYGDM', (104, 111, [], 1.0)),
#  ('NGVFQECC', (184, 192, [], 1.0)),
#  ('MENFVAF', (570, 577, [], 1.0)),
#  ('CDNQDTL', (287, 294, [], 1.0)),
#  ('ECFLSH', (123, 129, [], 1.0)),
#  ('ELTEFAKTC', (68, 77, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('LHTLFGDELCKV', (89, 101, [], 1.0)),
#  ('GPKLVV', (594, 600, [], 1.0)),
#  ('LPPLTAD', (324, 331, [], 1.0)),
#  ('FSALTPDET', (510, 519, [], 1.0)),
#  ('YLCDNQDT', (285, 293, [], 1.0)),
#  ('LPPLTAD', (324, 331, [], 1.0)),
#  ('SLRETYGD', (102, 110, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('ECFLSH', (123, 129, [], 1.0)),
#  ('LRETYGDM', (103, 111, [], 1.0)),
#  ('KYNGVF', (182, 188, [], 1.0)),
#  ('CFLSHKDD', (124, 132, [], 1.0)),
#  ('NKYNGVFQ', (181, 189, [], 1.0)),
#  ('STVFDKL', (393, 400, [], 1.0)),
#  ('GDELCKV', (94, 101, [], 1.0)),
#  ('LCTLPDTE', (535, 543, [], 1.0)),
#  ('QDTLSSKL', (290, 298, [], 1.0)),
#  ('CCDKPLLE', (300, 308, [], 1.0)),
#  ('DSPDLPKL', (131, 139, [], 1.0)),
#  ('DLPKLKPD', (134, 142, [], 1.0)),
#  ('DEKLFTFH', (525, 533, [], 1.0)),
#  ('CDEFKAD', (146, 153, [], 1.0)),
#  ('EATLEEC', (376, 383, [], 1.0)),
#  ('ANKYNGVFQ', (180, 189, [], 1.0)),
#  ('FGERAL', (228, 234, [], 1.0)),
#  ('CFLSHKDD', (124, 132, [], 1.0)),
#  ('LHTLFGDELCKV', (89, 101, [], 1.0)),
#  ('KEYEATL', (373, 380, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('ETYVPKAF', (517, 525, [], 1.0)),
#  ('LRETYGD', (103, 110, [], 1.0)),
#  ('EPQNLLKQN', (405, 414, [], 1.0)),
#  ('LVNELTEFA', (65, 74, [], 1.0)),
#  ('CCDKPLLE', (300, 308, [], 1.0)),
#  ('CDQFEKL', (414, 421, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('GDELCKV', (94, 101, [], 1.0)),
#  ('LRETYGD', (103, 110, [], 1.0)),
#  ('LHTLFGDEL', (89, 98, [], 1.0)),
#  ('LEECCAKDD', (379, 388, [], 1.0)),
#  ('STVFDKL', (393, 400, [], 1.0)),
#  ('LHTLFGDELCKV', (89, 101, [], 1.0)),
#  ('VEGPKL', (592, 598, [], 1.0)),
#  ('GDELCKV', (94, 101, [], 1.0)),
#  ('EQLKTVME', (564, 572, [], 1.0)),
#  ('CDQFEKL', (414, 421, [], 1.0)),
#  ('CCDKPLLE', (300, 308, [], 1.0)),
#  ('STVFDKL', (393, 400, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('VTKLVTD', (253, 260, [], 1.0)),
#  ('SVARLS', (237, 243, [], 1.0)),
#  ('ETYVPKA', (517, 524, [], 1.0)),
#  ('QNCDQFEKL', (412, 421, [], 1.0)),
#  ('EEQLKTVM', (563, 571, [], 1.0)),
#  ('QLKTVME', (565, 572, [], 1.0)),
#  ('CFLSHKDD', (124, 132, [], 1.0)),
#  ('PQNLLKQN', (406, 414, [], 1.0)),
#  ('LLPKLETM', (200, 208, [], 1.0)),
#  ('DEKLFTFH', (525, 533, [], 1.0)),
#  ('STVFDKL', (393, 400, [], 1.0)),
#  ('LRETYGDM', (103, 111, [], 1.0)),
#  ('SHKDDSPDLPKL', (127, 139, [], 1.0)),
#  ('AFSALTPDET', (509, 519, [0], 0.9)),
#  ('LAKYLCD', (282, 289, [], 1.0)),
#  ('FHADLCTL', (531, 539, [], 1.0)),
#  ('DEHVKLVN', (60, 68, [], 1.0)),
#  ('GPKLVVST', (594, 602, [], 1.0)),
#  ('KYDGVFQECCQ', (182, 193, [2], 0.9090909090909091)),
#  ('VEGPKLVV', (592, 600, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('HLVDEPQ', (401, 408, [], 1.0)),
#  ('LRCASLQ', (220, 227, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('KHLVDEPQNLLKQN', (400, 414, [], 1.0)),
#  ('ETYGDMADCCAK', (105, 117, [10], 0.9166666666666666)),
#  ('NQDTLSSKL', (289, 298, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('HLVDEPQNL', (401, 410, [], 1.0)),
#  ('QCPFDEHVK', (56, 65, [], 1.0)),
#  ('TPDETYVPKAF', (514, 525, [], 1.0)),
#  ('GPKLVV', (594, 600, [], 1.0)),
#  ('KYNGVFQE', (182, 190, [], 1.0)),
#  ('RLCVLH', (481, 487, [], 1.0)),
#  ('TPDETYVPKAF', (514, 525, [], 1.0)),
#  ('KHLVDEPQ', (400, 408, [], 1.0)),
#  ('TPDETYVPKAF', (514, 525, [], 1.0)),
#  ('LHTLFGDEL', (89, 98, [], 1.0)),
#  ('TEDYLSLL', (471, 479, [], 1.0)),
#  ('ACLLPKLETM', (198, 208, [], 1.0)),
#  ('SPDLPKL', (132, 139, [], 1.0)),
#  ('QQCPFDEHVK', (55, 65, [], 1.0)),
#  ('EPQNLLKQN', (405, 414, [], 1.0)),
#  ('KSHCLAEVE', (308, 317, [], 1.0)),
#  ('CDQFEKL', (414, 421, [], 1.0)),
#  ('HPEYAVSVLLR', (360, 371, [], 1.0)),
#  ('VTKLVTDLTK', (253, 263, [], 1.0)),
#  ('FEKLGEYG', (417, 425, [], 1.0)),
#  ('KYLCDNQDTL', (284, 294, [], 1.0)),
#  ('RFKDLGEEHF', (33, 43, [], 1.0)),
#  ('KHLVDEPQNLLKQ', (400, 413, [], 1.0)),
#  ('TLEECCAKDD', (378, 388, [], 1.0)),
#  ('RETYGDMADCC', (104, 115, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('NCDQFEKL', (413, 421, [], 1.0)),
#  ('HPEYAVSVLLR', (360, 371, [], 1.0)),
#  ('KEYEATLEEC', (373, 383, [], 1.0)),
#  ('NGVFQEC', (184, 191, [], 1.0)),
#  ('ACFAVE', (588, 594, [], 1.0)),
#  ('KHLVDEPQNLL', (400, 411, [], 1.0)),
#  ('EATLEECCAKDD', (376, 388, [], 1.0)),
#  ('KTVMENFV', (567, 575, [], 1.0)),
#  ('VTKLVTD', (253, 260, [], 1.0)),
#  ('ETYGDMADCCAK', (105, 117, [10], 0.9166666666666666)),
#  ('KYLCDNEDTL', (284, 294, [6], 0.9)),
#  ('KHLVDEPQNLLKQN', (400, 414, [], 1.0)),
#  ('FEKLGEYG', (417, 425, [], 1.0)),
#  ('LLPKLETM', (200, 208, [], 1.0)),
#  ('VTKLVTD', (253, 260, [], 1.0)),
#  ('DLPKLKPD', (134, 142, [], 1.0)),
#  ('ECFLSHK', (123, 130, [], 1.0)),
#  ('CYSTVFDKL', (391, 400, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('ECFLSHKD', (123, 131, [], 1.0)),
#  ('EQLKTVME', (564, 572, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('KSHCLAEVE', (308, 317, [], 1.0)),
#  ('ACLLPKLETM', (198, 208, [], 1.0)),
#  ('VEGPKL', (592, 598, [], 1.0)),
#  ('ETYVPKAF', (517, 525, [], 1.0)),
#  ('EFVEVTKL', (249, 257, [], 1.0)),
#  ('RFKDLGEEHF', (33, 43, [], 1.0)),
#  ('EFVEVTKL', (249, 257, [], 1.0)),
#  ('KEYEATLEECCA', (373, 385, [], 1.0)),
#  ('AFLGSFLYE', (347, 356, [], 1.0)),
#  ('ETYVPKAF', (517, 525, [], 1.0)),
#  ('HVKLVNELTE', (62, 72, [], 1.0)),
#  ('ACFAVEGPKL', (588, 598, [], 1.0)),
#  ('FAEDKDVCKN', (331, 341, [], 1.0)),
#  ('ECFLSHKD', (123, 131, [], 1.0)),
#  ('DEKLFTFH', (525, 533, [], 1.0)),
#  ('ECFLSHKD', (123, 131, [], 1.0)),
#  ('FAVEGPKL', (590, 598, [], 1.0)),
#  ('FDEHVKL', (59, 66, [], 1.0)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('STVFDKL', (393, 400, [], 1.0)),
#  ('ETYVPKAFDE', (517, 527, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('SLRETYG', (102, 109, [], 1.0)),
#  ('ECFLSHKD', (123, 131, [], 1.0)),
#  ('FGDELCKV', (93, 101, [], 1.0)),
#  ('ARLSQKFPKAE', (239, 250, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('DEKLFTF', (525, 532, [], 1.0)),
#  ('LPKLETM', (201, 208, [], 1.0)),
#  ('GEYGFQN', (421, 428, [], 1.0)),
#  ('RLSQKFPKAL', (240, 250, [9], 0.9)),
#  ('NCDQFEKL', (413, 421, [], 1.0)),
#  ('LLPKLETM', (200, 208, [], 1.0)),
#  ('GEYGFQ', (421, 427, [], 1.0)),
#  ('LCKVASLRE', (97, 106, [], 1.0)),
#  ('FAEDKDVCKN', (331, 341, [], 1.0)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('LPKLETM', (201, 208, [], 1.0)),
#  ('DLPKLKPD', (134, 142, [], 1.0)),
#  ('FAVEGPK', (590, 597, [], 1.0)),
#  ('PFDEHVKL', (58, 66, [], 1.0)),
#  ('KGLVLL', (43, 49, [], 1.0)),
#  ('RLSQKFPKAEF', (240, 251, [], 1.0)),
#  ('KHLVDEPQNLLKQ', (400, 413, [], 1.0)),
#  ('KECCHGDLL', (265, 274, [], 1.0)),
#  ('EACFAVEGPK', (587, 597, [], 1.0)),
#  ('DNQDTLSSKL', (288, 298, [], 1.0)),
#  ('PNTLCDE', (142, 149, [], 1.0)),
#  ('CDNQDTLSS', (287, 296, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('SPDLPKL', (132, 139, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('STVFDKLKH', (393, 402, [], 1.0)),
#  ('KYLCD', (284, 289, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('CPFDEHVK', (57, 65, [], 1.0)),
#  ('ACLLPKLETM', (198, 208, [], 1.0)),
#  ('DSPDLPK', (131, 138, [], 1.0)),
#  ('VMENFVAF', (569, 577, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('SQYLQQCPFDEHVK', (51, 65, [], 1.0)),
#  ('CKVASL', (98, 104, [], 1.0)),
#  ('EACFAVEGPK', (587, 597, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('VAFVDKC', (574, 581, [], 1.0)),
#  ('CTEDYLSLLLNR', (470, 482, [], 1.0)),
#  ('KDLGEEHF', (35, 43, [], 1.0)),
#  ('KTVMENF', (567, 574, [], 1.0)),
#  ('VFQECC', (186, 192, [], 1.0)),
#  ('KLVTDLTKVHKE', (255, 267, [], 1.0)),
#  ('YNGVFQEC', (183, 191, [], 1.0)),
#  ('AFSQYL', (49, 55, [], 1.0)),
#  ('DTLSSKLKE', (291, 300, [], 1.0)),
#  ('SERMPCTE', (465, 473, [], 1.0)),
#  ('LEECCAKDD', (379, 388, [], 1.0)),
#  ('ELTEFAKT', (68, 76, [], 1.0)),
#  ('CPFDEHVKLVN', (57, 68, [], 1.0)),
#  ('DTHKSELAHRF', (24, 35, [], 1.0)),
#  ('TLPDTEKQ', (537, 545, [], 1.0)),
#  ('HLVDEPQNL', (401, 410, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('QCPFDEHVK', (56, 65, [], 1.0)),
#  ('VTKLVTDLTKVHKE', (253, 267, [], 1.0)),
#  ('CFAVEGPK', (589, 597, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('LQECPFDEHVK', (54, 65, [2], 0.9090909090909091)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('ELTEFAK', (68, 75, [], 1.0)),
#  ('CAADDKEACF', (581, 591, [], 1.0)),
#  ('KEYEATL', (373, 380, [], 1.0)),
#  ('NLPPLTADF', (323, 332, [], 1.0)),
#  ('FAEDKDVCKN', (331, 341, [], 1.0)),
#  ('VEGPKLV', (592, 599, [], 1.0)),
#  ('KYLCDNQDTL', (284, 294, [], 1.0)),
#  ('FAKTCVADESHAGCE', (72, 87, [], 1.0)),
#  ('LGEEHFKG', (37, 45, [], 1.0)),
#  ('ALPENLPPLTA', (319, 330, [], 1.0)),
#  ('KHLVDEPQNLLKQ', (400, 413, [], 1.0)),
#  ('LKTVMEN', (566, 573, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('EEHFKGL', (39, 46, [], 1.0)),
#  ('YEATLEE', (375, 382, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('LQQCPFDEHVK', (54, 65, [], 1.0)),
#  ('CLLPKLETM', (199, 208, [], 1.0)),
#  ('LLYYANK', (176, 183, [], 1.0)),
#  ('RSLGKVG', (450, 457, [], 1.0)),
#  ('ELTEFAK', (68, 75, [], 1.0)),
#  ('LVNELTEF', (65, 73, [], 1.0)),
#  ('EATLEECCAK', (376, 386, [], 1.0)),
#  ('ADDKEACFA', (583, 592, [], 1.0)),
#  ('MREKVL', (207, 213, [], 1.0)),
#  ('FSQYL', (50, 55, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('LLPKLETM', (200, 208, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('LQQCPFDEHVK', (54, 65, [], 1.0)),
#  ('LFGDELCKV', (92, 101, [], 1.0)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('AEFVEVTKL', (248, 257, [], 1.0)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('KECCHGDLL', (265, 274, [], 1.0)),
#  ('AFSQYLQQ', (49, 57, [], 1.0)),
#  ('LAKYLCDN', (282, 290, [], 1.0)),
#  ('LRLAKEYEAT', (369, 379, [], 1.0)),
#  ('RLSQKFPKAE', (240, 250, [], 1.0)),
#  ('NELTEFAKTC', (67, 77, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('LAKEYEAT', (371, 379, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('HLVDEPQNL', (401, 410, [], 1.0)),
#  ('FGDELCK', (93, 100, [], 1.0)),
#  ('PNTLCDEF', (142, 150, [], 1.0)),
#  ('AFVDKCC', (575, 582, [], 1.0)),
#  ('LRETYGDMAD', (103, 113, [], 1.0)),
#  ('VEGPKLVV', (592, 600, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('LPKLETM', (201, 208, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('LPPLTAD', (324, 331, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('KHLVDEPQNLL', (400, 411, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('PDETYVPKA', (515, 524, [], 1.0)),
#  ('HLVDEPQN', (401, 409, [], 1.0)),
#  ('STVFDKLKH', (393, 402, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('LLYYANK', (176, 183, [], 1.0)),
#  ('YSTVFDKL', (392, 400, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('TLCDEFK', (144, 151, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('VEGPKLVV', (592, 600, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('ANKYNGVFQE', (180, 190, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('RLSQKFPKAE', (240, 250, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('PNTLCDEFKA', (142, 152, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('LQQCPFDEHVK', (54, 65, [], 1.0)),
#  ('TVFDKLKH', (394, 402, [], 1.0)),
#  ('GKYLYE', (158, 164, [], 1.0)),
#  ('KYNGVFQE', (182, 190, [], 1.0)),
#  ('TLCDEFKAD', (144, 153, [], 1.0)),
#  ('DLGEEHF', (36, 43, [], 1.0)),
#  ('KDLGEEHF', (35, 43, [], 1.0)),
#  ('FAEDKDVCKN', (331, 341, [], 1.0)),
#  ('CLLPKLETM', (199, 208, [], 1.0)),
#  ('DLPKLKPDPN', (134, 144, [], 1.0)),
#  ('CDQFEKLGEY', (414, 424, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('QCPFDEHVKLVN', (56, 68, [], 1.0)),
#  ('KDLGEEHF', (35, 43, [], 1.0)),
#  ('WGKYLY', (157, 163, [], 1.0)),
#  ('PCTEDYLSLL', (469, 479, [], 1.0)),
#  ('CFLSHKD', (124, 131, [], 1.0)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('QQCPFDEHV', (55, 64, [], 1.0)),
#  ('TLEECCA', (378, 385, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('DSPDLPKLKPD', (131, 142, [], 1.0)),
#  ('RLSQKFPKAE', (240, 250, [], 1.0)),
#  ('MENFVAFV', (570, 578, [], 1.0)),
#  ('PFDEHVKL', (58, 66, [], 1.0)),
#  ('ELTEFAKTC', (68, 77, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('ECCDKPLLEKS', (299, 310, [], 1.0)),
#  ('LQQCPFDEHVK', (54, 65, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('LLPKLE', (200, 206, [], 1.0)),
#  ('DKGACLLPKLETM', (195, 208, [], 1.0)),
#  ('AFDEKLFTFH', (523, 533, [], 1.0)),
#  ('QNCDQFEK', (412, 420, [], 1.0)),
#  ('ATLEECCAKDD', (377, 388, [], 1.0)),
#  ('DFAEDKDVCKN', (330, 341, [], 1.0)),
#  ('SPDLPKL', (132, 139, [], 1.0)),
#  ('CDQFEKLGEY', (414, 424, [], 1.0)),
#  ('GERALKAW', (229, 237, [], 1.0)),
#  ('DQFEKL', (415, 421, [], 1.0)),
#  ('LLPKLETMR', (200, 209, [], 1.0)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('LLPKLET', (200, 207, [], 1.0)),
#  ('HLVDEPQNLLK', (401, 412, [], 1.0)),
#  ('FGDELCKV', (93, 101, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('CDEFKADEKKF', (146, 157, [], 1.0)),
#  ('HEKTPVSEKVTKC', (486, 499, [], 1.0)),
#  ('SPDLPKL', (132, 139, [], 1.0)),
#  ('QNCDQFEK', (412, 420, [], 1.0)),
#  ('DKGACLLPKLE', (195, 206, [], 1.0)),
#  ('CDQFEKLGE', (414, 423, [], 1.0)),
#  ('VSRSLGKVG', (448, 457, [], 1.0)),
#  ('ECPFDEHVKLVN', (56, 68, [0], 0.9166666666666666)),
#  ('HLVDEPQNLLK', (401, 412, [], 1.0)),
#  ('VEGPKLV', (592, 599, [], 1.0)),
#  ('ALPENLPPLTA', (319, 330, [], 1.0)),
#  ('HVKLVDELTE', (62, 72, [5], 0.9)),
#  ('AFVDKC', (575, 581, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('QNCDQFEKLGEY', (412, 424, [], 1.0)),
#  ('FKDLGEEHFK', (34, 44, [], 1.0)),
#  ('FKDLGEEH', (34, 42, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('FGERALK', (228, 235, [], 1.0)),
#  ('TLPDTEKQLKKQ', (537, 549, [], 1.0)),
#  ('VTDLTKVHKEC', (257, 268, [], 1.0)),
#  ('HLVDEPQNLLK', (401, 412, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('EACFAVEGPK', (587, 597, [], 1.0)),
#  ('CPFDEHVK', (57, 65, [], 1.0)),
#  ('FAVEGPK', (590, 597, [], 1.0)),
#  ('SPDLPKL', (132, 139, [], 1.0)),
#  ('FGDELCK', (93, 100, [], 1.0)),
#  ('SQKFPKAE', (242, 250, [], 1.0)),
#  ('AFDEKLFTFH', (523, 533, [], 1.0)),
#  ('ACFAVEGPK', (588, 597, [], 1.0)),
#  ('VMENFVAFV', (569, 578, [], 1.0)),
#  ('HLVDEPQNLLK', (401, 412, [], 1.0)),
#  ('YYANKY', (178, 184, [], 1.0)),
#  ('RKVPQVSTPT', (435, 445, [], 1.0)),
#  ('AVEGPKL', (591, 598, [], 1.0)),
#  ('FKDLGEEH', (34, 42, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('HLVDEPQNLL', (401, 411, [], 1.0)),
#  ('ECFLSHKD', (123, 131, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('LRLAKEYE', (369, 377, [], 1.0)),
#  ('KQTALVELL', (547, 556, [], 1.0)),
#  ('KYLCDN', (284, 290, [], 1.0)),
#  ('ELTEFAKTAVAD', (68, 80, [8], 0.9166666666666666)),
#  ('ECFLSHK', (123, 130, [], 1.0)),
#  ('SELAHRF', (28, 35, [], 1.0)),
#  ('TLPDTEKQ', (537, 545, [], 1.0)),
#  ('DFAEDKDVCKNYQ', (330, 343, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('TLFGDELCKVAF', (91, 103, [11], 0.9166666666666666)),
#  ('GVFQECCQAED', (185, 196, [], 1.0)),
#  ('KSELAHRF', (27, 35, [], 1.0)),
#  ('TVFDKLKH', (394, 402, [], 1.0)),
#  ('CLLPKLETM', (199, 208, [], 1.0)),
#  ('QNCDQFEK', (412, 420, [], 1.0)),
#  ('PKLVVSTQ', (595, 603, [], 1.0)),
#  ('EQCPFDEHVKL', (55, 66, [0], 0.9090909090909091)),
#  ('WGKYL', (157, 162, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('SPDLPK', (132, 138, [], 1.0)),
#  ('DTLSSKLKE', (291, 300, [], 1.0)),
#  ('LPPLTAD', (324, 331, [], 1.0)),
#  ('LQQCPFD', (54, 61, [], 1.0)),
#  ('LLPKLET', (200, 207, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('LLPKLET', (200, 207, [], 1.0)),
#  ('ECFLSHKDD', (123, 132, [], 1.0)),
#  ('VLLRLAK', (367, 374, [], 1.0)),
#  ('VTKLVTDLTKVH', (253, 265, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('QNCDQFEK', (412, 420, [], 1.0)),
#  ('QQCPFDEHVKL', (55, 66, [], 1.0)),
#  ('LLPKLETM', (200, 208, [], 1.0)),
#  ('LCDEFK', (145, 151, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('VNELTEF', (66, 73, [], 1.0)),
#  ('FVEVTKLVTDLTKVH', (250, 265, [], 1.0)),
#  ('KYLCDNEDTLSSKL', (284, 298, [6], 0.9285714285714286)),
#  ('HEKTPVSEKVTKC', (486, 499, [], 1.0)),
#  ('THKSELAHRF', (25, 35, [], 1.0)),
#  ('KHLVDEPQNL', (400, 410, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('QNCDQFEK', (412, 420, [], 1.0)),
#  ('YSTVFDKLK', (392, 401, [], 1.0)),
#  ('FAEDKDVCKN', (331, 341, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('FGERALK', (228, 235, [], 1.0)),
#  ('LCKVASLR', (97, 105, [], 1.0)),
#  ('LLPKLET', (200, 207, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('FKDLGEEH', (34, 42, [], 1.0)),
#  ('KQNCDQFEKL', (411, 421, [], 1.0)),
#  ('LQQCPFDEHVK', (54, 65, [], 1.0)),
#  ('KHLVDEPQDLLKQ', (400, 413, [8], 0.9230769230769231)),
#  ('LFGDELCKV', (92, 101, [], 1.0)),
#  ('NCDQFEKL', (413, 421, [], 1.0)),
#  ('TLCDEFKA', (144, 152, [], 1.0)),
#  ('SALTPDETY', (511, 520, [], 1.0)),
#  ('VDEPQNL', (403, 410, [], 1.0)),
#  ('LLPKLE', (200, 206, [], 1.0)),
#  ('GKYLCDNQDTL', (283, 294, [0], 0.9090909090909091)),
#  ('FGDELCK', (93, 100, [], 1.0)),
#  ('FAEDKDVCKN', (331, 341, [], 1.0)),
#  ('AFDEKLF', (523, 530, [], 1.0)),
#  ('TPDETYVPK', (514, 523, [], 1.0)),
#  ('CLLPKLE', (199, 206, [], 1.0)),
#  ('RHPEYAVDVLLR', (359, 371, [7], 0.9166666666666666)),
#  ('KHLVDEPQNLLKE', (400, 413, [12], 0.9230769230769231)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('CDEFKA', (146, 152, [], 1.0)),
#  ('LPPLTAD', (324, 331, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('FAVEGPKL', (590, 598, [], 1.0)),
#  ('FVEVTK', (250, 256, [], 1.0)),
#  ('LLYYANKYN', (176, 185, [], 1.0)),
#  ('FGERALK', (228, 235, [], 1.0)),
#  ('CDKPLLEK', (301, 309, [], 1.0)),
#  ('LAKEYEAT', (371, 379, [], 1.0)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('DTHKSELAHRF', (24, 35, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('DDSPDLPK', (130, 138, [], 1.0)),
#  ('VNELTEFA', (66, 74, [], 1.0)),
#  ('LGEEHFKGL', (37, 46, [], 1.0)),
#  ('NELTEFA', (67, 74, [], 1.0)),
#  ('AEDKDVCKNY', (332, 342, [], 1.0)),
#  ('LKPDPNTLCDEFK', (138, 151, [], 1.0)),
#  ('ECFLSHKDD', (123, 132, [], 1.0)),
#  ('SLRETY', (102, 108, [], 1.0)),
#  ('QNCDQFEK', (412, 420, [], 1.0)),
#  ('FKDLGEEH', (34, 42, [], 1.0)),
#  ('EACFAVEGPK', (587, 597, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('ANKYNGVF', (180, 188, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('DEKLFT', (525, 531, [], 1.0)),
#  ('QNCDQFEK', (412, 420, [], 1.0)),
#  ('CPFDEHVKL', (57, 66, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('HLVDEPENLLK', (401, 412, [6], 0.9090909090909091)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('EQLKTVME', (564, 572, [], 1.0)),
#  ('AFDEKLF', (523, 530, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('VTKLVTDLTKVHKE', (253, 267, [], 1.0)),
#  ('LKPDPNTLCDEFK', (138, 151, [], 1.0)),
#  ('PCTEDYLSLLLNR', (469, 482, [], 1.0)),
#  ('KDLGEEHFKGL', (35, 46, [], 1.0)),
#  ('LPPLTAD', (324, 331, [], 1.0)),
#  ('EFVEVTK', (249, 256, [], 1.0)),
#  ('VTKLVTDLTKVHKE', (253, 267, [], 1.0)),
#  ('EPQNLLKQ', (405, 413, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('KDLGEEHF', (35, 43, [], 1.0)),
#  ('TVFDK', (394, 399, [], 1.0)),
#  ('FAVEGPK', (590, 597, [], 1.0)),
#  ('YLQQCPFDEHVK', (53, 65, [], 1.0)),
#  ('GFQNELLVRY', (424, 434, [4], 0.9)),
#  ('VSVLLR', (365, 371, [], 1.0)),
#  ('EVEKDALPE', (314, 323, [], 1.0)),
#  ('VTDLTKVHKEC', (257, 268, [], 1.0)),
#  ('LLPKLE', (200, 206, [], 1.0)),
#  ('YVPKAFD', (519, 526, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('GDELCKVAVL', (94, 104, [8], 0.9)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('FKDLGEEH', (34, 42, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('PFDEHVKLVN', (58, 68, [], 1.0)),
#  ('PFDEHVKL', (58, 66, [], 1.0)),
#  ('AVEGPKL', (591, 598, [], 1.0)),
#  ('NELTEFAK', (67, 75, [], 1.0)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('DDSPDLPK', (130, 138, [], 1.0)),
#  ('FDKLKHL', (396, 403, [], 1.0)),
#  ('NELTEFA', (67, 74, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('RCASLQKF', (221, 229, [], 1.0)),
#  ('LCDNQDTLSSKLL', (286, 299, [12], 0.9230769230769231)),
#  ('LGEEHFKGL', (37, 46, [], 1.0)),
#  ('AEDKDVCKNY', (332, 342, [], 1.0)),
#  ('DEKLFTF', (525, 532, [], 1.0)),
#  ('SHCLAEVEK', (309, 318, [], 1.0)),
#  ('YLYELAR', (160, 167, [], 1.0)),
#  ('SLRETYGD', (102, 110, [], 1.0)),
#  ('VDEPENLLKQ', (403, 413, [4], 0.9)),
#  ('DKGACLLPKLETM', (195, 208, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('GEEHFKGL', (38, 46, [], 1.0)),
#  ('KHLVDEPQNLL', (400, 411, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('CCAADDKEACFAVEGPK', (580, 597, [], 1.0)),
#  ('QYLQQCPFDEH', (52, 63, [], 1.0)),
#  ('YSTVFDKL', (392, 400, [], 1.0)),
#  ('DNQDTLSSKL', (288, 298, [], 1.0)),
#  ('KYLYELA', (159, 166, [], 1.0)),
#  ('LLNRLC', (478, 484, [], 1.0)),
#  ('LTEFAKT', (69, 76, [], 1.0)),
#  ('DEHVKLVNEL', (60, 70, [], 1.0)),
#  ('HLVDEPQNLLKQ', (401, 413, [], 1.0)),
#  ('LLSQKFPKAE', (240, 250, [0], 0.9)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('PKLKPDPN', (136, 144, [], 1.0)),
#  ('DEKKFWG', (152, 159, [], 1.0)),
#  ('TKLVTDL', (254, 261, [], 1.0)),
#  ('TYVPKAFDE', (518, 527, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('LEECCAKDD', (379, 388, [], 1.0)),
#  ('KLFTFHAD', (527, 535, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('LAKEYEAT', (371, 379, [], 1.0)),
#  ('LSHKDDSPDLPK', (126, 138, [], 1.0)),
#  ('STVFDK', (393, 399, [], 1.0)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('FDEHVKLVN', (59, 68, [], 1.0)),
#  ('DFAEDKDVCKN', (330, 341, [], 1.0)),
#  ('QECCEAEDKGACL', (188, 201, [4], 0.9230769230769231)),
#  ('FVEVTK', (250, 256, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('PHACYSTVFDKL', (388, 400, [], 1.0)),
#  ('LKPDPNTLCDEFK', (138, 151, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('KLFTFHAD', (527, 535, [], 1.0)),
#  ('TLPDTEKQLKKQ', (537, 549, [], 1.0)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('DLCTLPDTEKQL', (534, 546, [], 1.0)),
#  ('TPDETYVPK', (514, 523, [], 1.0)),
#  ('LVDELTEFAK', (65, 75, [2], 0.9)),
#  ('DSPDLPKLKPD', (131, 142, [], 1.0)),
#  ('LLPKLETM', (200, 208, [], 1.0)),
#  ('AWSVARLSQK', (235, 245, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('EVSRSLGKV', (447, 456, [], 1.0)),
#  ('DTHKSELAHRL', (24, 35, [10], 0.9090909090909091)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('NGVFEECCQAEDKGAC', (184, 200, [4], 0.9375)),
#  ('NQDTLSSKLKE', (289, 300, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('PKLVVSTQ', (595, 603, [], 1.0)),
#  ('KHLVDEPQDL', (400, 410, [8], 0.9)),
#  ('ALPENLPPLT', (319, 329, [], 1.0)),
#  ('AFDEKLFTF', (523, 532, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('LLQQCPFDEHVK', (53, 65, [0], 0.9166666666666666)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('LPKLETM', (201, 208, [], 1.0)),
#  ('SQKFPKAEFVEVTKF', (242, 257, [14], 0.9333333333333333)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('DEKLFTF', (525, 532, [], 1.0)),
#  ('QTALVELLK', (548, 557, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('KYLCDNQD', (284, 292, [], 1.0)),
#  ('FKDLGEEHFKG', (34, 45, [], 1.0)),
#  ('DFAEDKDVCKD', (330, 341, [10], 0.9090909090909091)),
#  ('KDDSPDLPKLKPD', (129, 142, [], 1.0)),
#  ('SALTPDETYVPKAF', (511, 525, [], 1.0)),
#  ('TPDETYVPK', (514, 523, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('ETYGDMADCCEK', (105, 117, [], 1.0)),
#  ('APELLYYANKYN', (173, 185, [], 1.0)),
#  ('ALPENLPPLTA', (319, 330, [], 1.0)),
#  ('LCKVASLRE', (97, 106, [], 1.0)),
#  ('VTKLVTDLTKVHKE', (253, 267, [], 1.0)),
#  ('TLFGDELCKVAKL', (91, 104, [11], 0.9230769230769231)),
#  ('KHLVDEPENLL', (400, 411, [7], 0.9090909090909091)),
#  ('GLFGDELCKV', (91, 101, [0], 0.9)),
#  ('GFQNALLVR', (424, 433, [], 1.0)),
#  ('QTALVELLK', (548, 557, [], 1.0)),
#  ('EPQNLLK', (405, 412, [], 1.0)),
#  ('LKPDPNTLCDEFK', (138, 151, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('FVEVTK', (250, 256, [], 1.0)),
#  ('GERALKAW', (229, 237, [], 1.0)),
#  ('LCDNQDTLSSKLK', (286, 299, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('TKLVTDLTKVH', (254, 265, [], 1.0)),
#  ('VEVTKLVTD', (251, 260, [], 1.0)),
#  ('AFVDKCCA', (575, 583, [], 1.0)),
#  ('TLFGDELCKVAC', (91, 103, [11], 0.9166666666666666)),
#  ('NECFLSH', (122, 129, [], 1.0)),
#  ('DEKLFT', (525, 531, [], 1.0)),
#  ('GVFQECAQAED', (185, 196, [6], 0.9090909090909091)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('ATLEECCAKDD', (377, 388, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('HLVDEPQNLLK', (401, 412, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('KLFTFH', (527, 533, [], 1.0)),
#  ('FDEKLFT', (524, 531, [], 1.0)),
#  ('VEGPKLVVS', (592, 601, [], 1.0)),
#  ('LRLAKEYEATLE', (369, 381, [], 1.0)),
#  ('EFVEVTK', (249, 256, [], 1.0)),
#  ('LQECPFDEHVK', (54, 65, [2], 0.9090909090909091)),
#  ('LPKLKPD', (135, 142, [], 1.0)),
#  ('CLLPKLET', (199, 207, [], 1.0)),
#  ('EATLEECCAKDD', (376, 388, [], 1.0)),
#  ('LTPDETYVPK', (513, 523, [], 1.0)),
#  ('NKYNGVFQE', (181, 190, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('VTKLVTDLTKVHKE', (253, 267, [], 1.0)),
#  ('LHTLFGDELC', (89, 99, [], 1.0)),
#  ('SQKFPKAEFVEVTKL', (242, 257, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('DFAEDKDVCKN', (330, 341, [], 1.0)),
#  ('NGVFQEC', (184, 191, [], 1.0)),
#  ('DSPDLPKLKPD', (131, 142, [], 1.0)),
#  ('GKYLY', (158, 163, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('VLHEKTPVSEKVTKC', (484, 499, [], 1.0)),
#  ('VEGPKLVV', (592, 600, [], 1.0)),
#  ('EKLFTFHAD', (526, 535, [], 1.0)),
#  ('YNGVFQEC', (183, 191, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('VTDLTKVHK', (257, 266, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('LLNRLCVL', (478, 486, [], 1.0)),
#  ('EKLFTFHAD', (526, 535, [], 1.0)),
#  ('YYANKYN', (178, 185, [], 1.0)),
#  ('ECCDKPLLEK', (299, 309, [], 1.0)),
#  ('EPQNLLK', (405, 412, [], 1.0)),
#  ('KDALPE', (317, 323, [], 1.0)),
#  ('FAEDKDVAKN', (331, 341, [7], 0.9)),
#  ('LCDEFKADEKKF', (145, 157, [], 1.0)),
#  ('GEEHFKGL', (38, 46, [], 1.0)),
#  ('CFAVEGPKLVV', (589, 600, [], 1.0)),
#  ('SLRETYGDM', (102, 111, [], 1.0)),
#  ('GFQNALLVR', (424, 433, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('FAEDKDVCKNY', (331, 342, [], 1.0)),
#  ('KLVTDLTKVHK', (255, 266, [], 1.0)),
#  ('VSRSLGKVG', (448, 457, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('DEKLFT', (525, 531, [], 1.0)),
#  ('KYLCDNQDTLSS', (284, 296, [], 1.0)),
#  ('AEDKDVCKNY', (332, 342, [], 1.0)),
#  ('FVEVTK', (250, 256, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('GFQNAL', (424, 430, [], 1.0)),
#  ('LGEEHFKG', (37, 45, [], 1.0)),
#  ('GDELCKVARL', (94, 104, [8], 0.9)),
#  ('DFAEDKD', (330, 337, [], 1.0)),
#  ('TLFGDELCKV', (91, 101, [], 1.0)),
#  ('TLFGDELCKVAAL', (91, 104, [11], 0.9230769230769231)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('PKAEFVE', (246, 253, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('RLCVL', (481, 486, [], 1.0)),
#  ('LNRLC', (479, 484, [], 1.0)),
#  ('DTHKSELAHRF', (24, 35, [], 1.0)),
#  ('FVEVTKLVTD', (250, 260, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('FAEDKDVCKNYQEAK', (331, 346, [], 1.0)),
#  ('ETYGDMADCCEK', (105, 117, [], 1.0)),
#  ('KYLCDNQDTLSS', (284, 296, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('VFDKLKHL', (395, 403, [], 1.0)),
#  ('FAEDKDVCKNY', (331, 342, [], 1.0)),
#  ('TLPDTEKELKKQ', (537, 549, [7], 0.9166666666666666)),
#  ('KLVTDLTKVHKE', (255, 267, [], 1.0)),
#  ('RETYGDMADC', (104, 114, [], 1.0)),
#  ('KCCAADDKEACFA', (579, 592, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('EHFKGL', (40, 46, [], 1.0)),
#  ('ALPENLPPL', (319, 328, [], 1.0)),
#  ('SPDLPK', (132, 138, [], 1.0)),
#  ('LKTVMENF', (566, 574, [], 1.0)),
#  ('LSQKFPKAE', (241, 250, [], 1.0)),
#  ('YYANKYN', (178, 185, [], 1.0)),
#  ('LCDEFKA', (145, 152, [], 1.0)),
#  ('LCKVASLRE', (97, 106, [], 1.0)),
#  ('TLFGDELCKVAL', (91, 103, [11], 0.9166666666666666)),
#  ('SQKFPKAEFVEVTKL', (242, 257, [], 1.0)),
#  ('VNELTEFAKTC', (66, 77, [], 1.0)),
#  ('SLRETY', (102, 108, [], 1.0)),
#  ('LKQNCDQFEK', (410, 420, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('ECFLSHKDD', (123, 132, [], 1.0)),
#  ('VSVLLR', (365, 371, [], 1.0)),
#  ('PFDEHVKL', (58, 66, [], 1.0)),
#  ('LKPDPNTLCDEFKAD', (138, 153, [], 1.0)),
#  ('YLYELAR', (160, 167, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('LHEKTPVSEKV', (485, 496, [], 1.0)),
#  ('FKDLGEEH', (34, 42, [], 1.0)),
#  ('NKYNGVFQ', (181, 189, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('LEECCAKDD', (379, 388, [], 1.0)),
#  ('NLPPLTADFAE', (323, 334, [], 1.0)),
#  ('TKLVTDLT', (254, 262, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('ETYVPKAFDE', (517, 527, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('VFDKLKHL', (395, 403, [], 1.0)),
#  ('KECCDKPLL', (298, 307, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('ADFAEDKD', (329, 337, [], 1.0)),
#  ('KQTALVELLK', (547, 557, [], 1.0)),
#  ('DELCKVASL', (95, 104, [], 1.0)),
#  ('KYLCDNQDTLSSKLK', (284, 299, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('VEVTKLVTDLTKVH', (251, 265, [], 1.0)),
#  ('SLRETYGDM', (102, 111, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('FKDLGEEHFKG', (34, 45, [], 1.0)),
#  ('LLNRLC', (478, 484, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('NLPPLTA', (323, 330, [], 1.0)),
#  ('SLLLNRL', (476, 483, [], 1.0)),
#  ('YAVSVLLRLAKE', (363, 375, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('KYLCDNQDTL', (284, 294, [], 1.0)),
#  ('RETYGDMA', (104, 112, [], 1.0)),
#  ('FVEVTKL', (250, 257, [], 1.0)),
#  ('FDKLKHL', (396, 403, [], 1.0)),
#  ('LVELLKHKPK', (551, 561, [], 1.0)),
#  ('FDEKLFTFH', (524, 533, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('LTPDETYVPK', (513, 523, [], 1.0)),
#  ('QEAKDAF', (342, 349, [], 1.0)),
#  ('VSRSLGKVG', (448, 457, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('LGEYGFQNELLVR', (420, 433, [8], 0.9230769230769231)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('VEVTKLVTDLTK', (251, 263, [], 1.0)),
#  ('GEEHFKGL', (38, 46, [], 1.0)),
#  ('YYANKY', (178, 184, [], 1.0)),
#  ('LKQNCDQF', (410, 418, [], 1.0)),
#  ('YLYELAR', (160, 167, [], 1.0)),
#  ('FLSHKDDSPDLPK', (125, 138, [], 1.0)),
#  ('KFPKAEF', (244, 251, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('YNGVFQECCQAEDK', (183, 197, [], 1.0)),
#  ('SQYLQQCPFDEHVK', (51, 65, [], 1.0)),
#  ('NCDQFEKLGEYGFQNALLVR', (413, 433, [], 1.0)),
#  ('LQQCPFDEHVK', (54, 65, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('ADFAEDKDVCK', (329, 340, [], 1.0)),
#  ('NKYNGVFQECCQ', (181, 193, [], 1.0)),
#  ('SHCLAEVEK', (309, 318, [], 1.0)),
#  ('DNQDTLSSKLK', (288, 299, [], 1.0)),
#  ('ANKYNGVFQ', (180, 189, [], 1.0)),
#  ('QTALVELLK', (548, 557, [], 1.0)),
#  ('DSPDLPKLKPD', (131, 142, [], 1.0)),
#  ('KDAFLGSFL', (345, 354, [], 1.0)),
#  ('ETYGDMADCCEK', (105, 117, [], 1.0)),
#  ('TLPDTEKQLKKQ', (537, 549, [], 1.0)),
#  ('YNGVFQECCQAEDK', (183, 197, [], 1.0)),
#  ('YNGVFQECCQAEDK', (183, 197, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('NELTEFAK', (67, 75, [], 1.0)),
#  ('GLHTLFGDELCKV', (88, 101, [0], 0.9230769230769231)),
#  ('CCAADDKEACFAVEGPK', (580, 597, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('LKQNCDQFEK', (410, 420, [], 1.0)),
#  ('SHCLAEVEK', (309, 318, [], 1.0)),
#  ('GPKLVVS', (594, 601, [], 1.0)),
#  ('KHLVDEPQNLL', (400, 411, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('FDALTPDETY', (510, 520, [1], 0.9)),
#  ('KDAFLGSF', (345, 353, [], 1.0)),
#  ('NELTEFA', (67, 74, [], 1.0)),
#  ('DFAEDKDVCKNY', (330, 342, [], 1.0)),
#  ('FDEKLFTF', (524, 532, [], 1.0)),
#  ('LKQNCDQFEK', (410, 420, [], 1.0)),
#  ('KETALVELLK', (547, 557, [1], 0.9)),
#  ('PKLVVS', (595, 601, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('DEKLFTF', (525, 532, [], 1.0)),
#  ('KSLHTLFGDE', (87, 97, [], 1.0)),
#  ('EGPKLVVS', (593, 601, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('DKEACFA', (585, 592, [], 1.0)),
#  ('LKPDPNTLCDEFK', (138, 151, [], 1.0)),
#  ('FKDLGEEHFKG', (34, 45, [], 1.0)),
#  ('SVLLRL', (366, 372, [], 1.0)),
#  ('YGFQNALLVR', (423, 433, [], 1.0)),
#  ('KFPKAEFVEVTKL', (244, 257, [], 1.0)),
#  ('KYDGVFQECCQA', (182, 194, [2], 0.9166666666666666)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('TALVELLK', (549, 557, [], 1.0)),
#  ('YLYELAR', (160, 167, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('LLYYANKY', (176, 184, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('EPQNLLK', (405, 412, [], 1.0)),
#  ('YNGVFQECCQAEDK', (183, 197, [], 1.0)),
#  ('ALPENLPPLTA', (319, 330, [], 1.0)),
#  ('DEKKFWGKYL', (152, 162, [], 1.0)),
#  ('LPKLKPD', (135, 142, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('DTHKSELAHRF', (24, 35, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('QTALVELLK', (548, 557, [], 1.0)),
#  ('CFLSH', (124, 129, [], 1.0)),
#  ('AFDEKL', (523, 529, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('ECCDKPLLEK', (299, 309, [], 1.0)),
#  ('CFLSHKD', (124, 131, [], 1.0)),
#  ('FWGKY', (156, 161, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('TPDETYVPKAFDE', (514, 527, [], 1.0)),
#  ('ECCDKPLLEK', (299, 309, [], 1.0)),
#  ('KHLVDEPENLL', (400, 411, [7], 0.9090909090909091)),
#  ('ALVELLK', (550, 557, [], 1.0)),
#  ('LSHKDDSPDLPK', (126, 138, [], 1.0)),
#  ('KKFWGKYLYE', (154, 164, [], 1.0)),
#  ('LSHKDDSPDLPK', (126, 138, [], 1.0)),
#  ('HCLAEVEKD', (310, 319, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('LPKLET', (201, 207, [], 1.0)),
#  ('LKQNCDQFEK', (410, 420, [], 1.0)),
#  ('DEHVKL', (60, 66, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('SHCLAEVEK', (309, 318, [], 1.0)),
#  ('DELCKV', (95, 101, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('GACLLPKLETM', (197, 208, [], 1.0)),
#  ('YSTVFDKLKHL', (392, 403, [], 1.0)),
#  ('RLCVL', (481, 486, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('YAPELLYYANKYN', (172, 185, [], 1.0)),
#  ('YSTVFDK', (392, 399, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('QKFPKAEFVEVTK', (243, 256, [], 1.0)),
#  ('DRADLAKYLAD', (278, 289, [9], 0.9090909090909091)),
#  ('AEFVEVTK', (248, 256, [], 1.0)),
#  ('FVEVTK', (250, 256, [], 1.0)),
#  ('FGDELCK', (93, 100, [], 1.0)),
#  ('LSQKFPKAE', (241, 250, [], 1.0)),
#  ('YLCDNQDTLSSK', (285, 297, [], 1.0)),
#  ('CDKPLLEKS', (301, 310, [], 1.0)),
#  ('NLPPLTAD', (323, 331, [], 1.0)),
#  ('QECCQAEDKGACL', (188, 201, [], 1.0)),
#  ('KDLGEEHF', (35, 43, [], 1.0)),
#  ('DLAKYLCD', (281, 289, [], 1.0)),
#  ('FSALTPDETY', (510, 520, [], 1.0)),
#  ('TLFGDELCKV', (91, 101, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('VVSTQTALA', (598, 607, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('LPKLETMR', (201, 209, [], 1.0)),
#  ('VLLRLA', (367, 373, [], 1.0)),
#  ('YLYELAR', (160, 167, [], 1.0)),
#  ('LVNELTEFA', (65, 74, [], 1.0)),
#  ('VEKDALPE', (315, 323, [], 1.0)),
#  ('QECCQAEDKGAC', (188, 200, [], 1.0)),
#  ('AEDKDVCKNY', (332, 342, [], 1.0)),
#  ('CTKPESERMPC', (460, 471, [], 1.0)),
#  ('LEECCA', (379, 385, [], 1.0)),
#  ('TLFGDELCKVASL', (91, 104, [], 1.0)),
#  ('DFAEDKDVCKNYQEAK', (330, 346, [], 1.0)),
#  ('DLGEEHFK', (36, 44, [], 1.0)),
#  ('VLLRLA', (367, 373, [], 1.0)),
#  ('KEYEATLEECCA', (373, 385, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('ALTPDETYVPK', (512, 523, [], 1.0)),
#  ('VEGPKL', (592, 598, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('KLFTFH', (527, 533, [], 1.0)),
#  ('FGDELCKVASL', (93, 104, [], 1.0)),
#  ('DEKLF', (525, 530, [], 1.0)),
#  ('DEKLFTFHAD', (525, 535, [], 1.0)),
#  ('ALTPDETYVPKA', (512, 524, [], 1.0)),
#  ('LFGDELCKVASL', (92, 104, [], 1.0)),
#  ('ALTPDETYVPK', (512, 523, [], 1.0)),
#  ('SHCLAEVEK', (309, 318, [], 1.0)),
#  ('DFAEDKDVCK', (330, 340, [], 1.0)),
#  ('EFVEVTKLVTDLTKVH', (249, 265, [], 1.0)),
#  ('LPKLKPD', (135, 142, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('SHCLAEVEK', (309, 318, [], 1.0)),
#  ('EFVEVTKLVTDLTK', (249, 263, [], 1.0)),
#  ('KTVMENF', (567, 574, [], 1.0)),
#  ('LRLAKEY', (369, 376, [], 1.0)),
#  ('FSQYLQ', (50, 56, [], 1.0)),
#  ('VFQECCQAEDK', (186, 197, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('PHACYSTVFDKLK', (388, 401, [], 1.0)),
#  ('ALTPDETYVPKA', (512, 524, [], 1.0)),
#  ('GLSQKFPKAE', (240, 250, [0], 0.9)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('GACLLPK', (197, 204, [], 1.0)),
#  ('PFDEHVKLVN', (58, 68, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('VTKLVTDLTKVHKE', (253, 267, [], 1.0)),
#  ('RHPEYAVSVLLR', (359, 371, [], 1.0)),
#  ('YYANKYNGVFQECCQ', (178, 193, [], 1.0)),
#  ('LLPKLETM', (200, 208, [], 1.0)),
#  ('LGEYGFQNALLVR', (420, 433, [], 1.0)),
#  ('SPDLPKLKPD', (132, 142, [], 1.0)),
#  ('QEAKDAFLG', (342, 351, [], 1.0)),
#  ('YLYELAR', (160, 167, [], 1.0)),
#  ('RKVPQVSTPT', (435, 445, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('GHLVDEPQNLLK', (400, 412, [0], 0.9166666666666666)),
#  ('FAVEGPKLVVS', (590, 601, [], 1.0)),
#  ('QCPFDEHVK', (56, 65, [], 1.0)),
#  ('RGHPEYAVSVLLR', (358, 371, [1], 0.9230769230769231)),
#  ('FAVEGPKLVV', (590, 600, [], 1.0)),
#  ('ACLLPKLE', (198, 206, [], 1.0)),
#  ('LCDEFKADEKKF', (145, 157, [], 1.0)),
#  ('QNCDQFEKLGEY', (412, 424, [], 1.0)),
#  ('GFQNALLVRY', (424, 434, [], 1.0)),
#  ('VLLRLA', (367, 373, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('LVNELTEFAK', (65, 75, [], 1.0)),
#  ('VEGPKL', (592, 598, [], 1.0)),
#  ('LVTDLTKVHKE', (256, 267, [], 1.0)),
#  ('KHLVDEPQDL', (400, 410, [8], 0.9)),
#  ('SHCLAEVEK', (309, 318, [], 1.0)),
#  ('KVPEVSTPTLVEVSR', (436, 451, [3], 0.9333333333333333)),
#  ('ALKAWSVAR', (232, 241, [], 1.0)),
#  ('DEKLF', (525, 530, [], 1.0)),
#  ('DVCKNYQEA', (336, 345, [], 1.0)),
#  ('DEKLF', (525, 530, [], 1.0)),
#  ('KDDPHACYSTV', (385, 396, [], 1.0)),
#  ('SFLYEYSR', (351, 359, [], 1.0)),
#  ('FKDLGEEHFK', (34, 44, [], 1.0)),
#  ('GPKLVVSTQ', (594, 603, [], 1.0)),
#  ('LFGDELCK', (92, 100, [], 1.0)),
#  ('LSQKFPKAE', (241, 250, [], 1.0)),
#  ...]

# %%
importlib.reload(map)
map.mapping_psms_protease_associated(mapped_sequences = mapped_psms,
                                     prot_seq = protein_norm,
                                     labels = proteases, 
                                     title = f"",
                                     palette = palette,
                                     output_folder = "../figures",
                                     output_file = f"psms_per_proteases.svg"
                                     )
# Out:
# Plotting contigs: 10it [00:00, 365.75it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 2
#       1 importlib.reload(map)
# ----> 2 map.mapping_psms_protease_associated(mapped_sequences = mapped_psms,
#       3                                      prot_seq = protein_norm,
#       4                                      labels = proteases,
#       5                                      title = f"",
#       6                                      palette = palette,
#       7                                      output_folder = "../figures",
#       8                                      output_file = f"psms_per_proteases.svg"
#       9                                      )
#
# File ~/Desktop/Marco/PhD/projects/InstaNexus/notebooks/../src/mapping.py:399, in mapping_psms_protease_associated(mapped_sequences, prot_seq, labels, palette, title, output_folder, output_file)
#     397 for idx, (_, mapping) in tqdm(enumerate(mapped_sequences), desc="Plotting contigs"):
#     398     start_index, end_index, mismatches, _ = mapping
# --> 399     lab = labels[idx]
#     400     ind += 1
#     401     placed = False
#
# IndexError: list index out of range

# %% [markdown]
# ### Assembly

# %%
kmers = dbg.get_kmers(final_psms, kmer_size=kmer_size)

# %%
edges = dbg.get_debruijn_edges_from_kmers(kmers)

# %%
assembled_contigs = dbg.assemble_contigs(edges)

# %%
assembled_contigs = sorted(assembled_contigs, key=len, reverse=True)

# %%
assembled_contigs = list(set(assembled_contigs))

# %%
assembled_contigs = [seq for seq in assembled_contigs if len(seq) > size_threshold]

# %%
assembled_contigs = sorted(assembled_contigs, key=len, reverse=True)

# %%
# assembled_contigs = list(dict.fromkeys(assembled_contigs))

# assembled_contigs = [seq for seq in assembled_contigs if len(seq) > size_threshold]

# assembled_contigs = sorted(assembled_contigs, key=len, reverse=True)

# set could be the problem

# %%
records = [Bio.SeqRecord.SeqRecord(Bio.Seq.Seq(contig), id=f"contig_{idx+1}",
                                description=f"length: {len(contig)}") for idx,
                                contig in enumerate(assembled_contigs)]

# %%
Bio.SeqIO.write(records, f"{combination_folder_out}/contigs/{ass_method}_contig_{conf}_{run}.fasta", "fasta")

# %%
mapped_contigs = map.process_protein_contigs_scaffold(assembled_contigs, protein_norm, max_mismatches, min_identity)

# %%
df_contigs_mapped = map.create_dataframe_from_mapped_sequences(data = mapped_contigs)

# %%
comp_stat.compute_assembly_statistics(df = df_contigs_mapped, sequence_type='contigs', output_folder = f'{combination_folder_out}/statistics', reference = protein_norm, **params)

# %%
map.mapping_substitutions(mapped_sequences = mapped_contigs,
                          prot_seq = protein_norm,
                          title= f"Contig mapping to reference sequence, {run}",
                          contig_colors = get_colors_from_run("nanobodies", is_scaffold=False),
                          match_color = get_colors_from_run("bsa", is_scaffold=False),
                          output_file=f"fig_X_{run}_substitution_map_contigs_dbg.svg",
                          output_folder="."
                          )

# %%
assembled_scaffolds = dbg.scaffold_iterative(assembled_contigs, min_overlap, size_threshold)

# %% [markdown]
# In case scaffold_iterative is too slow or does not work, it is recommeneded to run only the few iteration in the following raw cell

# %% [raw]
# assembled_scaffolds = dbg.create_scaffolds(assembled_contigs, min_overlap)
#
# assembled_scaffolds = list(set(assembled_scaffolds))
#
# assembled_scaffolds = sorted(assembled_scaffolds, key=len, reverse=True)
#
# assembled_scaffolds = [scaffold for scaffold in assembled_scaffolds if len(scaffold) > size_threshold]
#
# assembled_scaffolds = dbg.merge_sequences(assembled_scaffolds)
#
# assembled_scaffolds = list(set(assembled_scaffolds))
#
# assembled_scaffolds = sorted(assembled_scaffolds, key=len, reverse=True)
#
# assembled_scaffolds = [scaffold for scaffold in assembled_scaffolds if len(scaffold) > size_threshold]

# %%
records = []
for i, seq in enumerate(assembled_scaffolds):
    record = Bio.SeqRecord.SeqRecord(Bio.Seq.Seq(seq), id=f"scaffold_{i+1}", description=f"length: {len(seq)}")
    records.append(record)

# %%
Bio.SeqIO.write(records, f"{combination_folder_out}/scaffolds/{ass_method}_scaffold_{conf}_{kmer_size}_{run}.fasta", "fasta")

# %%
mapped_scaffolds = map.process_protein_contigs_scaffold(assembled_scaffolds, protein_norm, max_mismatches, min_identity)

# %%
df_scaffolds_mapped = map.create_dataframe_from_mapped_sequences(data = mapped_scaffolds)

# %%
comp_stat.compute_assembly_statistics(df = df_scaffolds_mapped, sequence_type='scaffolds', output_folder = f"{combination_folder_out}/statistics", reference = protein_norm, **params)

# %%
map.mapping_substitutions(mapped_sequences = mapped_scaffolds, prot_seq = protein_norm,
                          title=f"Scaffold mapping to reference sequence, {run} {chain}", contig_colors= get_colors_from_run("bsa", is_scaffold=True),
                          match_color= get_colors_from_run("bsa", is_scaffold=True), output_file=f"fig_X_{run}{chain}_substitution_map_scaffolds_dbg.svg",
                          output_folder="."
                          )

# %% [markdown]
# ### Clustering

# %%
scaffolds_folder_out = f"../outputs/{run}{chain}/{comb}/scaffolds"
print(f"scaffolds_folder_out: {scaffolds_folder_out}")

# %%
clus.cluster_fasta_files(input_folder = scaffolds_folder_out)

# %%
cluster_folder_out = os.path.join(scaffolds_folder_out, "cluster")
print(cluster_folder_out)

# %%
cluster_tsv_folder = os.path.join(scaffolds_folder_out, "cluster")
output_base_folder = os.path.join(scaffolds_folder_out, "cluster_fasta")

for fasta_file in os.listdir(scaffolds_folder_out):
    if fasta_file.endswith('.fasta'):
        fasta_path = os.path.join(scaffolds_folder_out, fasta_file)
        clus.process_fasta_and_clusters(fasta_path, cluster_tsv_folder, output_base_folder)

# %% [markdown]
# ### Alignment

# %%
cluster_fasta_folder = os.path.join(scaffolds_folder_out, "cluster_fasta") 
align_folder = os.path.join(scaffolds_folder_out, "align")
prep.create_directory(align_folder)

# %%
for cluster_folder in os.listdir(cluster_fasta_folder): 
    cluster_folder_path = os.path.join(cluster_fasta_folder, cluster_folder) 
    if os.path.isdir(cluster_folder_path): 
        
        output_cluster_folder = os.path.join(align_folder, cluster_folder) 
        os.makedirs(output_cluster_folder, exist_ok=True) 
            
        for fasta_file in os.listdir(cluster_folder_path): 
            if fasta_file.endswith('.fasta'): 
                fasta_file_path = os.path.join(cluster_folder_path, fasta_file)
                base_filename = os.path.splitext(fasta_file)[0] 
                output_file = os.path.join(output_cluster_folder, f"{base_filename}_out.afa")
                    
                align.align_or_copy_fasta(fasta_file_path, output_file)

print("All alignment tasks completed.")

# %% [markdown]
# ### Consensus

# %%
consensus_folder = os.path.join(scaffolds_folder_out, "consensus")

# %%
cons.process_alignment_files(align_folder, consensus_folder)

# %%
all_sequences = cons.load_all_consensus_sequences(consensus_folder)
